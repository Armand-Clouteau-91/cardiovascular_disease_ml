# %% [markdown]
# # 2. Model Training (Production)
# This notebook loads the processed data and trains the final **XGBoost Classifier** using the optimal hyperparameters found during Phase 1 optimization.

# %%
import pandas as pd
import numpy as np
import pickle
import os
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# 1. Load Processed Data
data_path = "../data/processed/final_dataset.csv"
df = pd.read_csv(data_path)

X = df.drop("cardio", axis=1)
y = df["cardio"]

# Standardize (Optional for XGBoost but good practice)
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)
print(f"Training Samples: {X_train.shape[0]}")
print(f"Test Samples:     {X_test.shape[0]}")
# Out:
# Training Samples: 55869
# Test Samples:     13968

# %%
# 2. Define Champion Model

params = {
    'n_estimators': 300,
    'learning_rate': 0.05,
    'max_depth': 5,
    'min_child_weight': 3,
    'gamma': 0.5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'eval_metric': 'logloss',
    'random_state': 42,
    'use_label_encoder': False
}

model = XGBClassifier(**params)
print("Training Model...")
model.fit(X_train, y_train)
print("Training Complete.")
# Out:
# Training Model...
# Training Complete.
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [10:45:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# 3. Validation
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print(f"\nFINAL TEST ACCURACY: {acc*100:.2f}%")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# FINAL TEST ACCURACY: 73.15%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74      6990
#            1       0.74      0.71      0.72      6978
#
#     accuracy                           0.73     13968
#    macro avg       0.73      0.73      0.73     13968
# weighted avg       0.73      0.73      0.73     13968

# %%
# 4. Save Model Artifact
models_dir = "../models"
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

model_path = os.path.join(models_dir, "xgboost_champion.json")
model.save_model(model_path)
print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ../models/xgboost_champion.json

# %% [markdown]
# # 5. Model Comparison

# %%
# Define dictionary of models to compare

models = {
    "XGBoost": model,
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(probability=True, random_state=42)
}

results = []

print("Training and evaluating comparison models...")

for name, clf in models.items():
    print(f"Processing {name}...")

    if name != "XGBoost":
        clf.fit(X_train, y_train)
    
    # Predict Hard Classes (Threshold=0.5)
    y_pred_comp = clf.predict(X_test)
    
    # Predict Probabilities for ROC-AUC
    try:
        # Get probability for the positive class (1)
        y_prob_comp = clf.predict_proba(X_test)[:, 1]
    except AttributeError:
        y_prob_comp = None
    
    # Calculate Metrics
    acc = accuracy_score(y_test, y_pred_comp)
    prec = precision_score(y_test, y_pred_comp)
    rec = recall_score(y_test, y_pred_comp)
    f1 = f1_score(y_test, y_pred_comp)
    roc = roc_auc_score(y_test, y_prob_comp) if y_prob_comp is not None else 0
    
    results.append({
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1 Score": f1,
        "ROC-AUC": roc
    })

# Create and Sort DataFrame for clean reporting
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Accuracy", ascending=False)

print("\nModel Comparison Summary:")
display(results_df)
# Out:
# Training and evaluating comparison models...
# Processing XGBoost...
# Processing Logistic Regression...
# Processing Random Forest...
# Processing KNN...
# Processing SVM...
#
# Model Comparison Summary:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0              XGBoost  0.731529   0.743146  0.706936  0.724589  0.797101
# 4                  SVM  0.727019   0.756275  0.669246  0.710104  0.777256
# 1  Logistic Regression  0.723940   0.742693  0.684580  0.712453  0.785371
# 3                  KNN  0.692726   0.695260  0.685297  0.690242  0.739173
# 2        Random Forest  0.683491   0.680197  0.691602  0.685852  0.740829
